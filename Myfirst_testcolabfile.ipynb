# %% [markdown]
# <a href="https://colab.research.google.com/github/kimc11/205data/blob/main/Myfirst_testcolabfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #In-class, we will practice how to upload data file to google colab

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/kimc11/205data/refs/heads/main/movies_imdb.csv")
df.head()
# Out:
#    Unnamed: 0      director_name  duration  director_facebook_likes  \
# 0           0      James Cameron     178.0                      0.0
# 1           1     Gore Verbinski     169.0                    563.0
# 2           2         Sam Mendes     148.0                      0.0
# 3           3  Christopher Nolan     164.0                  22000.0
# 4           4        Doug Walker       NaN                    131.0
#
#    actor_1_facebook_likes        gross     actor_1_name  \
# 0                  1000.0  760505847.0      CCH Pounder
# 1                 40000.0  309404152.0      Johnny Depp
# 2                 11000.0  200074175.0  Christoph Waltz
# 3                 27000.0  448130642.0        Tom Hardy
# 4                   131.0          NaN      Doug Walker
#
#                                   movie_title  facenumber_in_poster  \
# 0                                      Avatar                   0.0
# 1    Pirates of the Caribbean: At World's End                   0.0
# ...

# %% [markdown]
# #descibe: basic statistics about the dataset

# %%
df.describe()
# Out:
#         Unnamed: 0     duration  director_facebook_likes  \
# count  4916.000000  4901.000000              4814.000000
# mean   2457.500000   107.090798               691.014541
# std    1419.271292    25.286015              2832.954125
# min       0.000000     7.000000                 0.000000
# 25%    1228.750000    93.000000                 7.000000
# 50%    2457.500000   103.000000                48.000000
# 75%    3686.250000   118.000000               189.750000
# max    4915.000000   511.000000             23000.000000
#
#        actor_1_facebook_likes         gross  facenumber_in_poster  \
# count             4909.000000  4.054000e+03           4903.000000
# mean              6494.488491  4.764451e+07              1.377320
# std              15106.986884  6.737255e+07              2.023826
# min                  0.000000  1.620000e+02              0.000000
# 25%                607.000000  5.019656e+06              0.000000
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'director_name', 'duration', 'director_facebook_likes',
#        'actor_1_facebook_likes', 'gross', 'actor_1_name', 'movie_title',
#        'facenumber_in_poster', 'plot_keywords', 'language', 'content_rating',
#        'budget', 'title_year', 'imdb_score', 'movie_facebook_likes', 'genre'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               4916 non-null   int64
#  1   director_name            4814 non-null   object
#  2   duration                 4901 non-null   float64
#  3   director_facebook_likes  4814 non-null   float64
#  4   actor_1_facebook_likes   4909 non-null   float64
#  5   gross                    4054 non-null   float64
#  6   actor_1_name             4909 non-null   object
#  7   movie_title              4916 non-null   object
#  8   facenumber_in_poster     4903 non-null   float64
#  9   plot_keywords            4764 non-null   object
#  10  language                 4902 non-null   object
#  11  content_rating           4616 non-null   object
#  12  budget                   4432 non-null   float64
#  13  title_year               4810 non-null   float64
# ...

# %%
df.size
# Out:
# 83572

# %%
df.shape
# Out:
# (4916, 17)

# %%
df.head()
# Out:
#    Unnamed: 0      director_name  duration  director_facebook_likes  \
# 0           0      James Cameron     178.0                      0.0
# 1           1     Gore Verbinski     169.0                    563.0
# 2           2         Sam Mendes     148.0                      0.0
# 3           3  Christopher Nolan     164.0                  22000.0
# 4           4        Doug Walker       NaN                    131.0
#
#    actor_1_facebook_likes        gross     actor_1_name  \
# 0                  1000.0  760505847.0      CCH Pounder
# 1                 40000.0  309404152.0      Johnny Depp
# 2                 11000.0  200074175.0  Christoph Waltz
# 3                 27000.0  448130642.0        Tom Hardy
# 4                   131.0          NaN      Doug Walker
#
#                                   movie_title  facenumber_in_poster  \
# 0                                      Avatar                   0.0
# 1    Pirates of the Caribbean: At World's End                   0.0
# ...

# %%
df['kml']=df['mpg'] * 1.6/3.78
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mpg'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-825541219.py in <cell line: 0>()
# ----> 1 df['kml']=df['mpg'] * 1.6/3.78
#       2 df.head()
#
# ...

# %%
df['origin'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'origin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-646615374.py in <cell line: 0>()
# ----> 1 df['origin'].unique()
#
# ...

# %%
df['origin'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'origin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2464776888.py in <cell line: 0>()
# ----> 1 df['origin'].value_counts()
#
# ...

# %%
df.loc[3:15,: ]
# Out:
#     Unnamed: 0      director_name  duration  director_facebook_likes  \
# 3            3  Christopher Nolan     164.0                  22000.0
# 4            4        Doug Walker       NaN                    131.0
# 5            5     Andrew Stanton     132.0                    475.0
# 6            6          Sam Raimi     156.0                      0.0
# 7            7       Nathan Greno     100.0                     15.0
# 8            8        Joss Whedon     141.0                      0.0
# 9            9        David Yates     153.0                    282.0
# 10          10        Zack Snyder     183.0                      0.0
# 11          11       Bryan Singer     169.0                      0.0
# 12          12       Marc Forster     106.0                    395.0
# 13          13     Gore Verbinski     151.0                    563.0
# 14          14     Gore Verbinski     150.0                    563.0
# 15          15        Zack Snyder     143.0                      0.0
#
# ...

# %%
df['mpg'].hist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mpg'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3943468383.py in <cell line: 0>()
# ----> 1 df['mpg'].hist()
#
# ...

# %%
df_grouped=df['mpg'].groupby(df['origin'])
df_grouped.mean()
# Out:
# origin
# europe    27.891429
# japan     30.450633
# usa       20.083534
# Name: mpg, dtype: float64

# %%
df.loc[df['mpg']>20,['name', 'mpg']]
# Out:
#                              name   mpg
# 14          toyota corona mark ii  24.0
# 15                plymouth duster  22.0
# 17                  ford maverick  21.0
# 18                   datsun pl510  27.0
# 19   volkswagen 1131 deluxe sedan  26.0
# ..                            ...   ...
# 393               ford mustang gl  27.0
# 394                     vw pickup  44.0
# 395                 dodge rampage  32.0
# 396                   ford ranger  28.0
# 397                    chevy s-10  31.0
#
# [238 rows x 2 columns]

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/csv data/movies_imdb.csv")
df.head()
# Out:
#    Unnamed: 0      director_name  duration  director_facebook_likes  \
# 0           0      James Cameron     178.0                      0.0
# 1           1     Gore Verbinski     169.0                    563.0
# 2           2         Sam Mendes     148.0                      0.0
# 3           3  Christopher Nolan     164.0                  22000.0
# 4           4        Doug Walker       NaN                    131.0
#
#    actor_1_facebook_likes        gross     actor_1_name  \
# 0                  1000.0  760505847.0      CCH Pounder
# 1                 40000.0  309404152.0      Johnny Depp
# 2                 11000.0  200074175.0  Christoph Waltz
# 3                 27000.0  448130642.0        Tom Hardy
# 4                   131.0          NaN      Doug Walker
#
#                                   movie_title  facenumber_in_poster  \
# 0                                      Avatar                   0.0
# 1    Pirates of the Caribbean: At World's End                   0.0
# ...

# %% [markdown]
# Show the director, title and duration for the first 20 movies

# %%
df.describe()
# Out:
#         Unnamed: 0     duration  director_facebook_likes  \
# count  4916.000000  4901.000000              4814.000000
# mean   2457.500000   107.090798               691.014541
# std    1419.271292    25.286015              2832.954125
# min       0.000000     7.000000                 0.000000
# 25%    1228.750000    93.000000                 7.000000
# 50%    2457.500000   103.000000                48.000000
# 75%    3686.250000   118.000000               189.750000
# max    4915.000000   511.000000             23000.000000
#
#        actor_1_facebook_likes         gross  facenumber_in_poster  \
# count             4909.000000  4.054000e+03           4903.000000
# mean              6494.488491  4.764451e+07              1.377320
# std              15106.986884  6.737255e+07              2.023826
# min                  0.000000  1.620000e+02              0.000000
# 25%                607.000000  5.019656e+06              0.000000
# ...

# %%
df.loc[:20, ['director_name','duration','movie_title']]
# Out:
#         director_name  duration                                  movie_title
# 0       James Cameron     178.0                                       Avatar
# 1      Gore Verbinski     169.0     Pirates of the Caribbean: At World's End
# 2          Sam Mendes     148.0                                      Spectre
# 3   Christopher Nolan     164.0                        The Dark Knight Rises
# 4         Doug Walker       NaN   Star Wars: Episode VII - The Force Awakens
# 5      Andrew Stanton     132.0                                  John Carter
# 6           Sam Raimi     156.0                                 Spider-Man 3
# 7        Nathan Greno     100.0                                      Tangled
# 8         Joss Whedon     141.0                      Avengers: Age of Ultron
# 9         David Yates     153.0       Harry Potter and the Half-Blood Prince
# 10        Zack Snyder     183.0           Batman v Superman: Dawn of Justice
# ...

# %%
new_df=df[df.director_name=="James Cameron"]
new_df.loc[:, ['gross', 'movie_title','title_year']]
# Out:
#             gross                 movie_title  title_year
# 0     760505847.0                      Avatar      2009.0
# 26    658672302.0                     Titanic      1997.0
# 285   204843350.0  Terminator 2: Judgment Day      1991.0
# 288   146282411.0                   True Lies      1994.0
# 599    54222000.0                   The Abyss      1989.0
# 2455   85200000.0                      Aliens      1986.0
# 3508   38400000.0              The Terminator      1984.0

# %% [markdown]
# Show the total gross sales for movies directed by the speified director

# %%
print(new_df['gross'].sum())
# Out:
# 1948125910.0

# %% [markdown]
# Compute the average movie length by genre(use groupby)

# %%
genre_df=df.groupby('genre')
genre_df['duration'].mean()
# Out:
# genre
# Action         110.676577
# Adventure      106.482916
# Animation       82.229508
# Biography      125.412000
# Comedy          99.498090
# Crime          112.032544
# Documentary     93.204819
# Drama          113.164544
# Family          96.454545
# Fantasy        101.042553
# Film-Noir       95.000000
# Game-Show       60.000000
# History         90.000000
# Horror          96.574661
# Music           93.000000
# Musical        103.750000
# Mystery        107.531250
# Romance         85.500000
# Sci-Fi         100.076923
# Thriller       103.666667
# Western        106.000000
# Name: duration, dtype: float64

# %%
genre_df=df.groupby('genre')
df.sort_values('duration')
# Out:
#       Unnamed: 0     director_name  duration  director_facebook_likes  \
# 1930        1930               NaN       7.0                      NaN
# 2316        2316        Jane Clark       7.0                     23.0
# 3997        3997               NaN      11.0                      NaN
# 4564        4564       Clark Baker      14.0                      0.0
# 4342        4342  Robert Greenwald      20.0                     21.0
# ...          ...               ...       ...                      ...
# 4416        4416               NaN       NaN                      NaN
# 4502        4502      Wajahat Rauf       NaN                      3.0
# 4580        4580   Joseph Kosinski       NaN                    364.0
# 4825        4825         Valentine       NaN                      0.0
# 4863        4863    Daniel Mellitz       NaN                      0.0
#
#       actor_1_facebook_likes  gross       actor_1_name  \
# 1930                    45.0    NaN    Justin Fletcher
# ...
